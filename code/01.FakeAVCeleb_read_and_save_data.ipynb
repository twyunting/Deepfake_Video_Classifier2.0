# %% [markdown]
# # Author: [Yunting Chiu](https://www.linkedin.com/in/yuntingchiu/)
#
# A is real videos & real audio (RR), B includes three types as following:
# - real videos & fake audio (RF)
# - fake videos & real audio (FR)
# - fake videos & fake audio (FF)

# %% [markdown]
# # Import the Packages

# %%
import cv2
import numpy as np
import glob
import imageio
from PIL import Image
import cv2

# %% [markdown]
# # Training Data
# ## $X_1$: Frames
# # 1. save `REAL_A_Extracted` to `A` folder
#
# - total frames: 63663

# %%
folders = glob.glob('/content/drive/MyDrive/American_University/2021_Fall/DATA-642-001_Advanced Machine Learning/data/FakeAVCeleb/FakeAVCeleb_preprocessed/TRAIN/EXTRACTED/FRAMES/REAL_A_Extracted/*')
imagenames_list = []
for folder in folders:
    for f in glob.glob(folder+'/*.jpg'):
        imagenames_list.append(f)

frames_A = [] 
count = 1
for image in imagenames_list:
    name = str(count) + '.png'
    frames_A.append(imageio.imread(image))
    imageio.imwrite("/content/drive/MyDrive/American_University/2021_Fall/DATA-642-001_Advanced Machine Learning/data/data_train/frames/A/"+name, imageio.imread(image))
    count += 1

print(len(frames_A))
# Out:
# 63663

# %%
import matplotlib.pyplot as plt
plt.imshow(read_images[0])

# %% [markdown]
# ### 2.save `FAKE_RTVC_B_Extracted` to `BCD` folder
# - total frames: 11836

# %%
folders = glob.glob('/content/drive/MyDrive/American_University/2021_Fall/DATA-642-001_Advanced Machine Learning/data/FakeAVCeleb/FakeAVCeleb_preprocessed/TRAIN/EXTRACTED/FRAMES/FAKE_RTVC_B_Extracted/*')
imagenames_list = []
for folder in folders:
    for f in glob.glob(folder+'/*.jpg'):
        imagenames_list.append(f)

frames_B = [] 
count = 1
for image in imagenames_list:
    name = "FAKE_RTVC_B_Extracted" + str(count) + '.png'
    frames_B.append(imageio.imread(image))
    imageio.imwrite("/content/drive/MyDrive/American_University/2021_Fall/DATA-642-001_Advanced Machine Learning/data/data_train/frames/BCD/"+name, imageio.imread(image))
    count += 1

print(len(frames_B))
# Out:
# 11836

# %% [markdown]
# ### 3.save `FAKE_FACESWAP_C_Extracted` to `BCD` folder
# - total frames:

# %%
folders = glob.glob('/content/drive/MyDrive/American_University/2021_Fall/DATA-642-001_Advanced Machine Learning/data/FakeAVCeleb/FakeAVCeleb_preprocessed/TRAIN/EXTRACTED/FRAMES/FAKE_FACESWAP_C_Extracted/*')
imagenames_list = []
for folder in folders:
    for f in glob.glob(folder+'/*.jpg'):
        imagenames_list.append(f)

frames_C1 = [] 
count = 1
for image in imagenames_list:
    name = "FAKE_FACESWAP_C_Extracted" + str(count) + '.png'
    frames_C1.append(imageio.imread(image))
    imageio.imwrite("/content/drive/MyDrive/American_University/2021_Fall/DATA-642-001_Advanced Machine Learning/data/data_train/frames/BCD/"+name, imageio.imread(image))
    count += 1

print(len(frames_C1))

# %% [markdown]
# ### 4.save `FAKE_FSGAN_C_Extracted` to `BCD` folder
# - total frames:

# %%
folders = glob.glob('/content/drive/MyDrive/American_University/2021_Fall/DATA-642-001_Advanced Machine Learning/data/FakeAVCeleb/FakeAVCeleb_preprocessed/TRAIN/EXTRACTED/FRAMES/FAKE_FSGAN_C_Extracted/*')
imagenames_list = []
for folder in folders:
    for f in glob.glob(folder+'/*.jpg'):
        imagenames_list.append(f)

frames_C2 = [] 
count = 1
for image in imagenames_list:
    name = "FAKE_FSGAN_C_Extracted" + str(count) + '.png'
    frames_C2.append(imageio.imread(image))
    imageio.imwrite("/content/drive/MyDrive/American_University/2021_Fall/DATA-642-001_Advanced Machine Learning/data/data_train/frames/BCD/"+name, imageio.imread(image))
    count += 1

print(len(frames_C2))

# %% [markdown]
# ### 5.save `FAKE_W2L_C_Extracted` to `BCD` folder
# - total frames:

# %%
folders = glob.glob('/content/drive/MyDrive/American_University/2021_Fall/DATA-642-001_Advanced Machine Learning/data/FakeAVCeleb/FakeAVCeleb_preprocessed/TRAIN/EXTRACTED/FRAMES/FAKE_W2L_C_Extracted/*')
imagenames_list = []
for folder in folders:
    for f in glob.glob(folder+'/*.jpg'):
        imagenames_list.append(f)

frames_C3 = [] 
count = 1
for image in imagenames_list:
    name = "FAKE_W2L_C_Extracted" + str(count) + '.png'
    frames_C3.append(imageio.imread(image))
    imageio.imwrite("/content/drive/MyDrive/American_University/2021_Fall/DATA-642-001_Advanced Machine Learning/data/data_train/frames/BCD/"+name, imageio.imread(image))
    count += 1

print(len(frames_C3))

# %% [markdown]
# ### 6.save `FAKE_FACESWAP_D_W2L_Extracted` to `BCD` folder
# - total frames:

# %%
folders = glob.glob('/content/drive/MyDrive/American_University/2021_Fall/DATA-642-001_Advanced Machine Learning/data/FakeAVCeleb/FakeAVCeleb_preprocessed/TRAIN/EXTRACTED/FRAMES/FAKE_FACESWAP_D_W2L_Extracted/*')
imagenames_list = []
for folder in folders:
    for f in glob.glob(folder+'/*.jpg'):
        imagenames_list.append(f)

frames_D1 = [] 
count = 1
for image in imagenames_list:
    name = "FAKE_FACESWAP_D_W2L_Extracted" + str(count) + '.png'
    frames_D1.append(imageio.imread(image))
    imageio.imwrite("/content/drive/MyDrive/American_University/2021_Fall/DATA-642-001_Advanced Machine Learning/data/data_train/frames/BCD/"+name, imageio.imread(image))
    count += 1

print(len(frames_D1))

# %% [markdown]
# ### 7.save `FAKE_FSGAN_D_W2L_Extracted` to `BCD` folder
# - total frames:

# %%
folders = glob.glob('/content/drive/MyDrive/American_University/2021_Fall/DATA-642-001_Advanced Machine Learning/data/FakeAVCeleb/FakeAVCeleb_preprocessed/TRAIN/EXTRACTED/FRAMES/FAKE_FSGAN_D_W2L_Extracted/*')
imagenames_list = []
for folder in folders:
    for f in glob.glob(folder+'/*.jpg'):
        imagenames_list.append(f)

frames_D2 = [] 
count = 1
for image in imagenames_list:
    name = "FAKE_FSGAN_D_W2L_Extracted" + str(count) + '.png'
    frames_D2.append(imageio.imread(image))
    imageio.imwrite("/content/drive/MyDrive/American_University/2021_Fall/DATA-642-001_Advanced Machine Learning/data/data_train/frames/BCD/"+name, imageio.imread(image))
    count += 1

print(len(frames_D2))

# %% [markdown]
# ### 8.save `org_FAKE_W2L_D_Extracted` to `BCD` folder
# - total frames:

# %%
folders = glob.glob('/content/drive/MyDrive/American_University/2021_Fall/DATA-642-001_Advanced Machine Learning/data/FakeAVCeleb/FakeAVCeleb_preprocessed/TRAIN/EXTRACTED/FRAMES/org_FAKE_W2L_D_Extracted/*')
imagenames_list = []
for folder in folders:
    for f in glob.glob(folder+'/*.jpg'):
        imagenames_list.append(f)

frames_D3 = [] 
count = 1
for image in imagenames_list:
    name = "org_FAKE_W2L_D_Extracted" + str(count) + '.png'
    frames_D3.append(imageio.imread(image))
    imageio.imwrite("/content/drive/MyDrive/American_University/2021_Fall/DATA-642-001_Advanced Machine Learning/data/data_train/frames/BCD/"+name, imageio.imread(image))
    count += 1

print(len(frames_D3))

# %% [markdown]
# # References
# - https://stackoverflow.com/questions/49537604/how-to-read-multiple-images-from-multiple-folders-in-python/49539027
# - https://sites.google.com/view/fakeavcelebdash-lab/documentation?authuser=0
